# %%
import model
import numpy as np
import os
import time
from multiprocessing import Process
import random

# %%
def prepare_training_set(type, source):
    folder = f'{source}/{type}'
    samples = os.listdir(folder)

    train_sequences = []

    for sample in samples:

        sequence = []
    
        f = open(os.path.join(folder,sample))
        text = f.read()

        text = text.split('\n')

        for point in text:
            if len(point) < 2:
                continue

            point = point.replace('(',"")
            point = point.replace(')',"")

            point = point.split(',')
            point[0] = float(point[0])
            point[1] = float(point[1])
            point[2] = float(point[2])

            sequence.append(point)

        train_sequences.append(sequence)

    return train_sequences

def prepare_test_set(type, source):
    # test data
    folder = f'{source}/{type}'
    samples = os.listdir(folder)

    test_sequences = []

    for sample in samples:

        sequence = []
    
        f = open(os.path.join(folder,sample))
        text = f.read()

        text = text.split('\n')

        for point in text:
            if len(point) < 2:
                continue

            point = point.replace('(',"")
            point = point.replace(')',"")

            point = point.split(',')
            point[0] = float(point[0])
            point[1] = float(point[1])
            point[2] = float(point[2])

            sequence.append(point)

        test_sequences.append([sequence, type])
        
    return test_sequences

# %%
def model_info(model):
    info = model.model_info()
    print(f"Model : {info[0]}")
    print(f"Hidden states : {info[1]}")
    print(f"PI : {info[2]}")
    print(f"A : {info[3]}")
    print(f"Mean : {info[4]}")
    print(f"Variance : {info[5]}")

# %%
def train(model, set):
    model.train(set)

# %%
def test(models, sequence, true_label):
    best = -np.inf
    label = ''

    print(10*"*")
    for model in models:
        score = model.classify(sequence)
        print(f"Model : {model.get_label()} | score = {score} | for class : {true_label}")
        if score > best:
            best = score
            label = model.get_label()
    print(10*"*")

    return true_label == label

# %%
# Initialize models + number of hidden states
hidden_states = 3

# circle
HMM_circle = model.HMM(hidden_states, 'circle')

# diagonal left
HMM_diagonal_left = model.HMM(hidden_states, 'diagonal_left')

# diagonal right
HMM_diagonal_right = model.HMM(hidden_states, 'diagonal_right')

# Horizontal
HMM_horizontal = model.HMM(hidden_states, 'horizontal')

# Vertical
HMM_vertical = model.HMM(hidden_states, 'vertical')

model_set = [HMM_circle, HMM_diagonal_left, HMM_diagonal_right, HMM_horizontal, HMM_vertical]

# %%
source_training = 'clean_data'
source_test = 'clean_data2'

circle_training_set = prepare_training_set('circle', source_training)
circle_test_set = prepare_test_set('circle', source_test)

diagonal_left_training_set = prepare_training_set('diagonal_left', source_training)
diagonal_left_test_set = prepare_test_set('diagonal_left', source_test)

diagonal_right_training_set = prepare_training_set('diagonal_right', source_training)
diagonal_right_test_set = prepare_test_set('diagonal_right', source_test)

horizontal_training_set = prepare_training_set('horizontal', source_training)
horizontal_test_set = prepare_test_set('horizontal', source_test)

vertical_training_set = prepare_training_set('vertical', source_training)
vertical_test_set = prepare_test_set('vertical', source_test)


test_set = circle_test_set+diagonal_left_test_set+diagonal_right_test_set+horizontal_test_set+vertical_test_set
random.shuffle(test_set)

processes = [
    Process(target=train, args=(HMM_circle, circle_training_set)),
    Process(target=train, args=(HMM_diagonal_left, diagonal_left_training_set)),
    Process(target=train, args=(HMM_diagonal_right, diagonal_right_training_set)),
    Process(target=train, args=(HMM_horizontal, horizontal_training_set)),
    Process(target=train, args=(HMM_vertical, vertical_training_set)),
]

# %%
# train models

start = time.time()

for p in processes:
    p.start()

for p in processes:
    p.join()

end = time.time()
# Out:
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar multiply
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar multiply
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:190: RuntimeWarning: invalid value encountered in subtract
#   log_gamma -= np.max(log_gamma, axis=1, keepdims=True)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar multiply
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:190: RuntimeWarning: invalid value encountered in subtract
#   log_gamma -= np.max(log_gamma, axis=1, keepdims=True)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar multiply
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar multiply
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:207: RuntimeWarning: overflow encountered in exp
#   xi_ij = np.exp(log_xi)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:207: RuntimeWarning: overflow encountered in exp
#   xi_ij = np.exp(log_xi)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:190: RuntimeWarning: invalid value encountered in subtract
#   log_gamma -= np.max(log_gamma, axis=1, keepdims=True)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:190: RuntimeWarning: invalid value encountered in subtract
#   log_gamma -= np.max(log_gamma, axis=1, keepdims=True)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:190: RuntimeWarning: invalid value encountered in subtract
#   log_gamma -= np.max(log_gamma, axis=1, keepdims=True)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:207: RuntimeWarning: overflow encountered in exp
#   xi_ij = np.exp(log_xi)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:207: RuntimeWarning: overflow encountered in exp
#   xi_ij = np.exp(log_xi)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:207: RuntimeWarning: overflow encountered in exp
#   xi_ij = np.exp(log_xi)
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar add
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar add
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:67: RuntimeWarning: overflow encountered in scalar add
#   terms += self.A[i][state] * self.B(sequence[t+1], state) * beta[t+1][state]
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:223: RuntimeWarning: invalid value encountered in divide
#   self.A = A_accum / row_sums
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1671888/687544136.py", line 2, in train
#     model.train(set)
#     ~~~~~~~~~~~^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 162, in train
#     seq_evidence = self.update_parameters_all_sequences(sequences)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 183, in update_parameters_all_sequences
#     alpha = self.forward(sequence)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 36, in forward
#     alpha[0][index] = self.PI[index] + self.B(sequence[0], index)
#                                        ~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 242, in B
#     log_prob = multivariate_normal.logpdf(observation, mean=self.mu[hidden_state], cov=cov)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 560, in logpdf
#     params = self._process_parameters(mean, cov, allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 425, in _process_parameters
#     psd = _PSD(cov, allow_singular=allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 168, in __init__
#     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/linalg/_decomp.py", line 458, in eigh
#     a1 = _asarray_validated(a, check_finite=check_finite)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/_lib/_util.py", line 537, in _asarray_validated
#     a = toarray(a)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 656, in asarray_chkfinite
#     raise ValueError(
#         "array must not contain infs or NaNs")
# ValueError: array must not contain infs or NaNs
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:223: RuntimeWarning: invalid value encountered in divide
#   self.A = A_accum / row_sums
# Process Process-2:
# Traceback (most recent call last):
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1671888/687544136.py", line 2, in train
#     model.train(set)
#     ~~~~~~~~~~~^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 162, in train
#     seq_evidence = self.update_parameters_all_sequences(sequences)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 183, in update_parameters_all_sequences
#     alpha = self.forward(sequence)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 36, in forward
#     alpha[0][index] = self.PI[index] + self.B(sequence[0], index)
#                                        ~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 242, in B
#     log_prob = multivariate_normal.logpdf(observation, mean=self.mu[hidden_state], cov=cov)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 560, in logpdf
#     params = self._process_parameters(mean, cov, allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 425, in _process_parameters
#     psd = _PSD(cov, allow_singular=allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 168, in __init__
#     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/linalg/_decomp.py", line 458, in eigh
#     a1 = _asarray_validated(a, check_finite=check_finite)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/_lib/_util.py", line 537, in _asarray_validated
#     a = toarray(a)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 656, in asarray_chkfinite
#     raise ValueError(
#         "array must not contain infs or NaNs")
# ValueError: array must not contain infs or NaNs
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:223: RuntimeWarning: invalid value encountered in divide
#   self.A = A_accum / row_sums
# Process Process-3:
# Traceback (most recent call last):
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1671888/687544136.py", line 2, in train
#     model.train(set)
#     ~~~~~~~~~~~^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 162, in train
#     seq_evidence = self.update_parameters_all_sequences(sequences)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 183, in update_parameters_all_sequences
#     alpha = self.forward(sequence)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 36, in forward
#     alpha[0][index] = self.PI[index] + self.B(sequence[0], index)
#                                        ~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 242, in B
#     log_prob = multivariate_normal.logpdf(observation, mean=self.mu[hidden_state], cov=cov)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 560, in logpdf
#     params = self._process_parameters(mean, cov, allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 425, in _process_parameters
#     psd = _PSD(cov, allow_singular=allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 168, in __init__
#     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/linalg/_decomp.py", line 458, in eigh
#     a1 = _asarray_validated(a, check_finite=check_finite)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/_lib/_util.py", line 537, in _asarray_validated
#     a = toarray(a)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 656, in asarray_chkfinite
#     raise ValueError(
#         "array must not contain infs or NaNs")
# ValueError: array must not contain infs or NaNs
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:223: RuntimeWarning: invalid value encountered in divide
#   self.A = A_accum / row_sums
# Process Process-5:
# Traceback (most recent call last):
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1671888/687544136.py", line 2, in train
#     model.train(set)
#     ~~~~~~~~~~~^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 162, in train
#     seq_evidence = self.update_parameters_all_sequences(sequences)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 183, in update_parameters_all_sequences
#     alpha = self.forward(sequence)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 36, in forward
#     alpha[0][index] = self.PI[index] + self.B(sequence[0], index)
#                                        ~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 242, in B
#     log_prob = multivariate_normal.logpdf(observation, mean=self.mu[hidden_state], cov=cov)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 560, in logpdf
#     params = self._process_parameters(mean, cov, allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 425, in _process_parameters
#     psd = _PSD(cov, allow_singular=allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 168, in __init__
#     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/linalg/_decomp.py", line 458, in eigh
#     a1 = _asarray_validated(a, check_finite=check_finite)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/_lib/_util.py", line 537, in _asarray_validated
#     a = toarray(a)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 656, in asarray_chkfinite
#     raise ValueError(
#         "array must not contain infs or NaNs")
# ValueError: array must not contain infs or NaNs
# /home/beaver/Documents/erica/ML/repo/ML1/model.py:223: RuntimeWarning: invalid value encountered in divide
#   self.A = A_accum / row_sums
# Process Process-4:
# Traceback (most recent call last):
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/beaver/anaconda3/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1671888/687544136.py", line 2, in train
#     model.train(set)
#     ~~~~~~~~~~~^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 162, in train
#     seq_evidence = self.update_parameters_all_sequences(sequences)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 183, in update_parameters_all_sequences
#     alpha = self.forward(sequence)
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 36, in forward
#     alpha[0][index] = self.PI[index] + self.B(sequence[0], index)
#                                        ~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/Documents/erica/ML/repo/ML1/model.py", line 242, in B
#     log_prob = multivariate_normal.logpdf(observation, mean=self.mu[hidden_state], cov=cov)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 560, in logpdf
#     params = self._process_parameters(mean, cov, allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 425, in _process_parameters
#     psd = _PSD(cov, allow_singular=allow_singular)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/stats/_multivariate.py", line 168, in __init__
#     s, u = scipy.linalg.eigh(M, lower=lower, check_finite=check_finite)
#            ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/linalg/_decomp.py", line 458, in eigh
#     a1 = _asarray_validated(a, check_finite=check_finite)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/scipy/_lib/_util.py", line 537, in _asarray_validated
#     a = toarray(a)
#   File "/home/beaver/anaconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py", line 656, in asarray_chkfinite
#     raise ValueError(
#         "array must not contain infs or NaNs")
# ValueError: array must not contain infs or NaNs

# %%
# test models

correct = 0
for sequence in test_set:
    
    if test(model_set, np.array(sequence[0]), sequence[1]):
        correct += 1

accuracy = correct/len(test_set)*100
print("Accuracy : ",accuracy,"%")
print("Training time: ",(end-start),"s")
# Out:
# **********
# Model : circle | score = 1.4319456220014484 | for class : horizontal
# Model : diagonal_left | score = 1.43194562200147 | for class : horizontal
# Model : diagonal_right | score = 1.4319456220014564 | for class : horizontal
# Model : horizontal | score = 1.431945622001492 | for class : horizontal
# Model : vertical | score = 1.4319456220014632 | for class : horizontal
# **********
# **********
# Model : circle | score = 1.4319456220014484 | for class : vertical
# Model : diagonal_left | score = 1.431945622001471 | for class : vertical
# Model : diagonal_right | score = 1.4319456220014573 | for class : vertical
# Model : horizontal | score = 1.4319456220014941 | for class : vertical
# Model : vertical | score = 1.4319456220014641 | for class : vertical
# **********
# **********
# Model : circle | score = 1.4319456220014524 | for class : circle
# Model : diagonal_left | score = 1.4319456220014906 | for class : circle
# Model : diagonal_right | score = 1.4319456220014668 | for class : circle
# Model : horizontal | score = 1.4319456220015296 | for class : circle
# Model : vertical | score = 1.4319456220014786 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014468 | for class : horizontal
# Model : diagonal_left | score = 1.431945622001463 | for class : horizontal
# Model : diagonal_right | score = 1.4319456220014533 | for class : horizontal
# Model : horizontal | score = 1.4319456220014797 | for class : horizontal
# Model : vertical | score = 1.4319456220014581 | for class : horizontal
# **********
# **********
# Model : circle | score = 1.43194562200145 | for class : circle
# Model : diagonal_left | score = 1.431945622001479 | for class : circle
# Model : diagonal_right | score = 1.4319456220014608 | for class : circle
# Model : horizontal | score = 1.4319456220015085 | for class : circle
# Model : vertical | score = 1.43194562200147 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014537 | for class : diagonal_right
# Model : diagonal_left | score = 1.431945622001498 | for class : diagonal_right
# Model : diagonal_right | score = 1.4319456220014704 | for class : diagonal_right
# Model : horizontal | score = 1.431945622001543 | for class : diagonal_right
# Model : vertical | score = 1.4319456220014843 | for class : diagonal_right
# **********
# **********
# Model : circle | score = 1.4319456220014568 | for class : diagonal_right
# Model : diagonal_left | score = 1.4319456220015128 | for class : diagonal_right
# Model : diagonal_right | score = 1.431945622001478 | for class : diagonal_right
# Model : horizontal | score = 1.4319456220015696 | for class : diagonal_right
# Model : vertical | score = 1.4319456220014954 | for class : diagonal_right
# **********
# **********
# Model : circle | score = 1.4319456220014546 | for class : circle
# Model : diagonal_left | score = 1.4319456220015014 | for class : circle
# Model : diagonal_right | score = 1.4319456220014724 | for class : circle
# Model : horizontal | score = 1.4319456220015494 | for class : circle
# Model : vertical | score = 1.431945622001487 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014506 | for class : diagonal_left
# Model : diagonal_left | score = 1.4319456220014817 | for class : diagonal_left
# Model : diagonal_right | score = 1.4319456220014624 | for class : diagonal_left
# Model : horizontal | score = 1.4319456220015134 | for class : diagonal_left
# Model : vertical | score = 1.431945622001472 | for class : diagonal_left
# **********
# **********
# Model : circle | score = 1.4319456220014506 | for class : circle
# Model : diagonal_left | score = 1.4319456220014817 | for class : circle
# Model : diagonal_right | score = 1.4319456220014624 | for class : circle
# Model : horizontal | score = 1.4319456220015137 | for class : circle
# Model : vertical | score = 1.4319456220014724 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014484 | for class : vertical
# Model : diagonal_left | score = 1.43194562200147 | for class : vertical
# Model : diagonal_right | score = 1.4319456220014566 | for class : vertical
# Model : horizontal | score = 1.4319456220014921 | for class : vertical
# Model : vertical | score = 1.4319456220014635 | for class : vertical
# **********
# **********
# Model : circle | score = 1.4319456220014475 | for class : horizontal
# Model : diagonal_left | score = 1.4319456220014648 | for class : horizontal
# Model : diagonal_right | score = 1.431945622001454 | for class : horizontal
# Model : horizontal | score = 1.4319456220014826 | for class : horizontal
# Model : vertical | score = 1.4319456220014595 | for class : horizontal
# **********
# **********
# Model : circle | score = 1.431945622001451 | for class : diagonal_left
# Model : diagonal_left | score = 1.4319456220014835 | for class : diagonal_left
# Model : diagonal_right | score = 1.4319456220014635 | for class : diagonal_left
# Model : horizontal | score = 1.4319456220015165 | for class : diagonal_left
# Model : vertical | score = 1.4319456220014735 | for class : diagonal_left
# **********
# **********
# Model : circle | score = 1.4319456220014564 | for class : circle
# Model : diagonal_left | score = 1.4319456220015099 | for class : circle
# Model : diagonal_right | score = 1.4319456220014766 | for class : circle
# Model : horizontal | score = 1.4319456220015647 | for class : circle
# Model : vertical | score = 1.4319456220014932 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014484 | for class : vertical
# Model : diagonal_left | score = 1.4319456220014692 | for class : vertical
# Model : diagonal_right | score = 1.4319456220014564 | for class : vertical
# Model : horizontal | score = 1.4319456220014906 | for class : vertical
# Model : vertical | score = 1.4319456220014626 | for class : vertical
# **********
# **********
# Model : circle | score = 1.4319456220014484 | for class : vertical
# Model : diagonal_left | score = 1.4319456220014706 | for class : vertical
# Model : diagonal_right | score = 1.431945622001457 | for class : vertical
# Model : horizontal | score = 1.4319456220014937 | for class : vertical
# Model : vertical | score = 1.431945622001464 | for class : vertical
# **********
# **********
# Model : circle | score = 1.4319456220014501 | for class : diagonal_right
# Model : diagonal_left | score = 1.4319456220014795 | for class : diagonal_right
# Model : diagonal_right | score = 1.4319456220014612 | for class : diagonal_right
# Model : horizontal | score = 1.4319456220015094 | for class : diagonal_right
# Model : vertical | score = 1.4319456220014706 | for class : diagonal_right
# **********
# **********
# Model : circle | score = 1.431945622001456 | for class : diagonal_right
# Model : diagonal_left | score = 1.4319456220015083 | for class : diagonal_right
# Model : diagonal_right | score = 1.4319456220014757 | for class : diagonal_right
# Model : horizontal | score = 1.431945622001562 | for class : diagonal_right
# Model : vertical | score = 1.4319456220014921 | for class : diagonal_right
# **********
# **********
# Model : circle | score = 1.4319456220014497 | for class : vertical
# Model : diagonal_left | score = 1.4319456220014772 | for class : vertical
# Model : diagonal_right | score = 1.43194562200146 | for class : vertical
# Model : horizontal | score = 1.4319456220015052 | for class : vertical
# Model : vertical | score = 1.4319456220014688 | for class : vertical
# **********
# **********
# Model : circle | score = 1.4319456220014501 | for class : circle
# Model : diagonal_left | score = 1.4319456220014788 | for class : circle
# Model : diagonal_right | score = 1.4319456220014608 | for class : circle
# Model : horizontal | score = 1.4319456220015079 | for class : circle
# Model : vertical | score = 1.43194562200147 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014521 | for class : diagonal_left
# Model : diagonal_left | score = 1.4319456220014897 | for class : diagonal_left
# Model : diagonal_right | score = 1.4319456220014664 | for class : diagonal_left
# Model : horizontal | score = 1.4319456220015279 | for class : diagonal_left
# Model : vertical | score = 1.4319456220014781 | for class : diagonal_left
# **********
# **********
# Model : circle | score = 1.4319456220014481 | for class : horizontal
# Model : diagonal_left | score = 1.4319456220014697 | for class : horizontal
# Model : diagonal_right | score = 1.4319456220014564 | for class : horizontal
# Model : horizontal | score = 1.4319456220014912 | for class : horizontal
# Model : vertical | score = 1.431945622001463 | for class : horizontal
# **********
# **********
# Model : circle | score = 1.4319456220014495 | for class : circle
# Model : diagonal_left | score = 1.431945622001475 | for class : circle
# Model : diagonal_right | score = 1.431945622001459 | for class : circle
# Model : horizontal | score = 1.4319456220015014 | for class : circle
# Model : vertical | score = 1.431945622001467 | for class : circle
# **********
# **********
# Model : circle | score = 1.431945622001452 | for class : circle
# Model : diagonal_left | score = 1.4319456220014881 | for class : circle
# Model : diagonal_right | score = 1.4319456220014655 | for class : circle
# Model : horizontal | score = 1.4319456220015252 | for class : circle
# Model : vertical | score = 1.4319456220014768 | for class : circle
# **********
# **********
# Model : circle | score = 1.4319456220014477 | for class : horizontal
# Model : diagonal_left | score = 1.4319456220014668 | for class : horizontal
# Model : diagonal_right | score = 1.4319456220014548 | for class : horizontal
# Model : horizontal | score = 1.4319456220014861 | for class : horizontal
# Model : vertical | score = 1.4319456220014608 | for class : horizontal
# **********
# **********
# Model : circle | score = 1.4319456220014528 | for class : diagonal_left
# Model : diagonal_left | score = 1.431945622001493 | for class : diagonal_left
# Model : diagonal_right | score = 1.431945622001468 | for class : diagonal_left
# Model : horizontal | score = 1.4319456220015336 | for class : diagonal_left
# Model : vertical | score = 1.4319456220014803 | for class : diagonal_left
# **********
# **********
# Model : circle | score = 1.4319456220014577 | for class : diagonal_right
# Model : diagonal_left | score = 1.4319456220015174 | for class : diagonal_right
# Model : diagonal_right | score = 1.4319456220014801 | for class : diagonal_right
# Model : horizontal | score = 1.4319456220015783 | for class : diagonal_right
# Model : vertical | score = 1.431945622001499 | for class : diagonal_right
# **********
# **********
# Model : circle | score = 1.431945622001451 | for class : diagonal_left
# Model : diagonal_left | score = 1.431945622001484 | for class : diagonal_left
# Model : diagonal_right | score = 1.4319456220014635 | for class : diagonal_left
# Model : horizontal | score = 1.431945622001517 | for class : diagonal_left
# Model : vertical | score = 1.4319456220014737 | for class : diagonal_left
# **********
# Accuracy :  17.857142857142858 %
# Training time:  5.646594524383545 s

# %%
'''
for model in model_set:
    model_info(model)
'''
# Out:
# '\nfor model in model_set:\n    model_info(model)\n'
